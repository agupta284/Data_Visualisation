# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from numpy.random import random,randn,randint,uniform,sample

# %%
tips = sns.load_dataset('tips')
flight = sns.load_dataset('flights')
car = sns.load_dataset('car_crashes')
iris = sns.load_dataset('iris')

# %%
flight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.pairplot(iris,hue='species')

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
flight['year'].unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
plt.subplots(figsize=(15,8))
sns.barplot(x='year',y='passengers',hue='month',data=flight)

# %%
x = flight['year']
y=flight['passengers']

# %%
a = sns.jointplot(x,y,kind='kde')
a.plot_joint(plt.scatter,c = 'w',s=40,linewidth=1,marker='+')
a.ax_joint.collections[1].set_alpha(0.1)

# %%
c=sns.PairGrid(iris)
c.map_diag(sns.kdeplot)
c.map_offdiag(sns.kdeplot,)
